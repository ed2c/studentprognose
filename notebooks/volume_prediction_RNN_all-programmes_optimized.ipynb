# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import json
import numpy as np
import itertools
from scripts.load_data import *
import optuna

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor

import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
configuration = load_configuration("../configuration/configuration.json")

paths = configuration["paths"]
data_student_numbers_f = pd.read_excel(paths["path_student_count_first-years"])
data_student_numbers_h = pd.read_excel(paths["path_student_count_higher-years"])
data_student_numbers_v = pd.read_excel(paths["path_student_volume"])

# %%
combined_data_student_numbers = data_student_numbers_f.merge(data_student_numbers_h, on=["Croho groepeernaam", "Herkomst", "Collegejaar"])
combined_data_student_numbers = combined_data_student_numbers.rename(columns={"Aantal_studenten_x": "Aantal_studenten_f", "Aantal_studenten_y": "Aantal_studenten_h"})
combined_data_student_numbers
# Out:
#       Collegejaar                                 Croho groepeernaam Herkomst  \
# 0            2012                                      M Geneeskunde       NL
# 1            2013                                      M Geneeskunde       NL
# 2            2014                                      M Geneeskunde       NL
# 3            2015                                      M Geneeskunde       NL
# 4            2016                                      M Geneeskunde       NL
# ...           ...                                                ...      ...
# 2176         2016  M Leraar Voorbereidend Hoger Onderwijs in Gods...       NL
# 2177         2014  M Leraar Voorbereidend Hoger Onderwijs in Natu...       NL
# 2178         2015  M Leraar Voorbereidend Hoger Onderwijs in Natu...       NL
# 2179         2017  M Leraar Voorbereidend Hoger Onderwijs in Natu...       NL
# 2180         2012                                M Kunstgeschiedenis       NL
#
#       Aantal_studenten_f  Aantal_studenten_h
# 0                    180                 868
# 1                    173                 892
# 2                    175                 916
# 3                     21                1086
# 4                    148                 984
# ...                  ...                 ...
# 2176                   1                   1
# 2177                   3                   1
# 2178                   1                   1
# 2179                   2                   1
# 2180                   1                   1
#
# [2181 rows x 5 columns]

# %%
combined_data_student_numbers[combined_data_student_numbers["Croho groepeernaam"] == "B Sociologie"]
# Out:
#       Collegejaar Croho groepeernaam Herkomst  Aantal_studenten_f  \
# 1839         2012       B Sociologie       NL                  49
# 1840         2013       B Sociologie       NL                  51
# 1841         2014       B Sociologie       NL                  38
# 1842         2015       B Sociologie       NL                  32
# 1843         2016       B Sociologie       NL                  44
# 1844         2017       B Sociologie       NL                  31
# 1845         2018       B Sociologie       NL                  43
# 1846         2019       B Sociologie       NL                  48
# 1847         2020       B Sociologie       NL                  63
# 1848         2021       B Sociologie       NL                  86
# 1849         2022       B Sociologie       NL                  79
# 1850         2023       B Sociologie       NL                  66
# 1851         2013       B Sociologie      EER                   7
# 1852         2014       B Sociologie      EER                   5
# 1853         2016       B Sociologie      EER                   1
# 1854         2019       B Sociologie      EER                   1
#
#       Aantal_studenten_h
# 1839                  76
# 1840                  88
# 1841                 108
# 1842                 105
# 1843                  95
# 1844                  98
# 1845                  89
# 1846                  99
# 1847                  99
# 1848                 111
# 1849                 141
# 1850                 162
# 1851                   1
# 1852                   2
# 1853                   4
# 1854                   2

# %%
predict_year = 2023

all_unique_years = np.sort(combined_data_student_numbers["Collegejaar"].unique())

# %%
def objective(trial):
    look_back = trial.suggest_int("look_back", 1, 10)
    nr_of_epochs = trial.suggest_int("nr_of_epochs", 3, 40)

    total_mae = 0.0
    count = 0.0

    for programme, origin in itertools.product(np.sort(combined_data_student_numbers["Croho groepeernaam"].unique()), np.sort(combined_data_student_numbers["Herkomst"].unique())):
        data = combined_data_student_numbers
        data = data.sort_values(by=["Collegejaar"])
        train = data[(data["Collegejaar"] < predict_year) & (data['Croho groepeernaam'] == programme) & (data["Herkomst"] == origin)]
        true_label = data[(data["Collegejaar"] == predict_year) & (data['Croho groepeernaam'] == programme) & (data["Herkomst"] == origin)]
        if len(true_label) == 0 or len(train) == 0:
            continue

        train_dataset = []
        for year in all_unique_years:
            year_train = train[train["Collegejaar"] == year]
            if len(year_train) == 0:
                train_dataset.append([0])
            else:
                train_dataset.append([year_train["Aantal_studenten_h"].iloc[0]])

        def create_dataset(dataset, look_back=1):
            dataX, dataY = [], []
            for i in range(len(dataset)-look_back-1):
                a = dataset[i:(i+look_back), 0]
                dataX.append(a)
                dataY.append(dataset[i + look_back, 0])
            return np.array(dataX), np.array(dataY)

        scaler = MinMaxScaler(feature_range=(0, 1))
        train_dataset = scaler.fit_transform(train_dataset)

        X_train, Y_train = create_dataset(train_dataset, look_back)

        trainX = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))

        model = Sequential()
        model.add(Input(shape=(1, look_back)))
        model.add(LSTM(units=4))
        model.add(Dense(8, activation='relu'))
        model.add(Dense(1, activation='linear'))

        model.compile(loss='mean_squared_error', optimizer='adam')
        model.fit(trainX, Y_train, epochs=nr_of_epochs, batch_size=1, verbose=0)

        test = train_dataset[-look_back:]

        reshaped_test = np.reshape(test, (1, 1, look_back))

        prediction = model.predict(reshaped_test, verbose=0)
        prediction = scaler.inverse_transform(prediction)
        
        mae = abs(prediction - true_label["Aantal_studenten_h"].iloc[0])
        print(f"{programme}, {origin}: {prediction} => {mae}")

        total_mae += mae
        count += 1.0

    final_mae = total_mae / count
    print(f"Final MAE: {final_mae}")
    print(final_mae[0][0])

# %%
study = optuna.create_study()
study.optimize(objective, n_trials=20)

print(study.best_params)

# MAE: 27.77, look_back: 6 en epochs: 35
# Out:
# [I 2024-05-14 11:10:04,031] A new study created in memory with name: no-name-c45d5571-b3ef-4e18-8f4e-e721222a5e8d
# B Algemene Cultuurwetenschappen, EER: [[3.9627576]] => [[32.037243]]
# B Algemene Cultuurwetenschappen, NL: [[23.762774]] => [[53.23723]]
# B Algemene Cultuurwetenschappen, Niet-EER: [[1.6670116]] => [[7.3329883]]
# B Artificial Intelligence, EER: [[11.7804365]] => [[72.21957]]
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000194B977EF20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# B Artificial Intelligence, NL: [[49.950603]] => [[225.0494]]
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000194BBA6A7A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# B Artificial Intelligence, Niet-EER: [[2.4955137]] => [[13.504486]]
# B Bedrijfskunde, EER: [[9.170171]] => [[70.82983]]
# B Bedrijfskunde, NL: [[160.03485]] => [[854.96515]]
# B Bedrijfskunde, Niet-EER: [[3.0797994]] => [[14.9202]]
# B Bestuurskunde, NL: [[63.527252]] => [[130.47275]]
# B Biology, EER: [[21.560995]] => [[102.439]]
# B Biology, NL: [[120.33598]] => [[120.66402]]
# B Biology, Niet-EER: [[2.2835546]] => [[20.716446]]
# B Artificial Intelligence, Niet-EER: [[6.9728317]] => [[9.027168]]
# B Bedrijfskunde, EER: [[27.798317]] => [[52.201683]]
# B Bedrijfskunde, NL: [[530.9948]] => [[484.0052]]
# B Bedrijfskunde, Niet-EER: [[13.975779]] => [[4.0242214]]
# B Bestuurskunde, NL: [[161.26099]] => [[32.739014]]
# B Biology, EER: [[58.17598]] => [[65.82402]]
# B Biology, NL: [[229.94653]] => [[11.053467]]
# B Biology, Niet-EER: [[12.264069]] => [[10.735931]]
# B Biomedische Wetenschappen, NL: [[141.55263]] => [[52.447372]]
# B Chemistry, EER: [[9.477796]] => [[15.522204]]
# B Chemistry, NL: [[86.35307]] => [[9.353073]]
# B Chemistry, Niet-EER: [[3.4295082]] => [[6.570492]]
# B Communicatie- en Informatiewetenschappen, EER: [[33.282757]] => [[12.717243]]
# B Communicatie- en Informatiewetenschappen, NL: [[242.08148]] => [[36.081482]]
# B Communicatie- en Informatiewetenschappen, Niet-EER: [[7.933908]] => [[1.933908]]
# B Communicatiewetenschap, NL: [[161.52332]] => [[63.476685]]
# B Computing Science, EER: [[32.219685]] => [[65.78032]]
# B Computing Science, NL: [[188.16528]] => [[156.83472]]
# B Computing Science, Niet-EER: [[9.357463]] => [[15.642537]]
# B Culturele Antropologie en Ontwikkelingssociologie, NL: [[70.79822]] => [[42.201782]]
# B Duitse Taal en Cultuur, NL: [[28.574417]] => [[11.574417]]
# B Economie en Bedrijfseconomie, EER: [[22.769197]] => [[5.2308025]]
# B Economie en Bedrijfseconomie, NL: [[332.30347]] => [[46.696533]]
# B Economie en Bedrijfseconomie, Niet-EER: [[9.267084]] => [[4.732916]]
# B English Language and Culture, EER: [[9.425243]] => [[8.574757]]
# B English Language and Culture, NL: [[166.19135]] => [[2.1913452]]
# B English Language and Culture, Niet-EER: [[0.6189228]] => [[1.3810772]]
# B European Law School, EER: [[2.0766132]] => [[0.07661319]]
# B European Law School, NL: [[113.94288]] => [[33.05712]]
# B Filosofie, EER: [[11.301373]] => [[45.698627]]
# B Filosofie, NL: [[66.41346]] => [[167.58655]]
# B Filosofie, Niet-EER: [[1.3551346]] => [[2.6448655]]
# B Geneeskunde, EER: [[11.042471]] => [[6.042471]]
# B Geneeskunde, NL: [[658.4855]] => [[176.51453]]
# B Geografie, Planologie en Milieu, NL: [[202.23816]] => [[145.76184]]
# B Geschiedenis, EER: [[1.7371348]] => [[4.262865]]
# B Geschiedenis, NL: [[227.05005]] => [[98.94995]]
# B Geschiedenis, Niet-EER: [[0.20372349]] => [[0.7962765]]
# B Griekse en Latijnse Taal en Cultuur, NL: [[24.828012]] => [[19.171988]]
# B Kunstgeschiedenis, EER: [[-1.4901161e-08]] => [[3.]]
# B Kunstgeschiedenis, NL: [[33.2467]] => [[31.7533]]
# B Molecular Life Sciences, EER: [[17.171764]] => [[14.828236]]
# B Molecular Life Sciences, NL: [[103.04262]] => [[68.95738]]
# B Molecular Life Sciences, Niet-EER: [[5.99029]] => [[6.00971]]
# B Natuur- en Sterrenkunde, EER: [[5.8819113]] => [[2.8819113]]
# M Linguistics and Communication Sciences (research), NL: [[4.4621153]] => [[4.5378847]]
# M Linguistics and Communication Sciences (research), Niet-EER: [[2.4512455]] => [[2.5487545]]
# M Mathematics, EER: [[1.0975324]] => [[0.9024676]]
# M Mathematics, NL: [[40.713978]] => [[8.286022]]
# M Medical Biology, EER: [[13.778579]] => [[25.22142]]
# M Medical Biology, NL: [[189.22627]] => [[79.77373]]
# M Medical Biology, Niet-EER: [[4.0577283]] => [[5.9422717]]
# M Molecular Mechanisms of Disease (research), EER: [[6.1806064]] => [[3.8193936]]
# M Molecular Mechanisms of Disease (research), NL: [[14.629541]] => [[3.3704586]]
# M Molecular Mechanisms of Disease (research), Niet-EER: [[3.5111222]] => [[1.4888778]]
# M Molecular Sciences, EER: [[12.842518]] => [[6.157482]]
# M Molecular Sciences, NL: [[131.31145]] => [[1.6885529]]
# M Molecular Sciences, Niet-EER: [[3.549035]] => [[1.5490351]]
# M Nederlands Recht, NL: [[397.7783]] => [[203.22171]]
# M Noord-Amerika Studies, NL: [[11.31823]] => [[7.3182297]]
# M Notarieel Recht, NL: [[39.52108]] => [[30.47892]]
# M Onderneming en Recht (research), NL: [[4.9480844]] => [[4.0519156]]
# M Onderwijswetenschappen, NL: [[37.144146]] => [[10.855854]]
# M Oudheidstudies, NL: [[7.3126044]] => [[0.31260443]]
# M Pedagogische Wetenschappen, NL: [[195.18114]] => [[60.818863]]
# M Physics and Astronomy, EER: [[6.591814]] => [[14.408186]]
# M Physics and Astronomy, NL: [[68.75018]] => [[51.249817]]
# M Physics and Astronomy, Niet-EER: [[1.9145247]] => [[6.0854754]]
# M Political Science, EER: [[4.0006347]] => [[1.0006347]]
# M Political Science, NL: [[48.872368]] => [[21.127632]]
# M Political Science, Niet-EER: [[0.92205423]] => [[0.07794577]]
# M Psychologie, EER: [[34.73488]] => [[17.734879]]
# M Psychologie, NL: [[93.86936]] => [[44.13064]]
# M Psychologie, Niet-EER: [[0.03258986]] => [[0.96741015]]
# M Social and Cultural Science: Comparative Research on Societies (research), EER: [[1.1409055]] => [[1.8590945]]
# M Social and Cultural Science: Comparative Research on Societies (research), NL: [[15.533538]] => [[7.533538]]
# M Sociologie, NL: [[5.5021195]] => [[3.4978805]]
# M Spatial Planning, EER: [[4.660355]] => [[6.339645]]
# M Spatial Planning, NL: [[43.830536]] => [[39.169464]]
# M Spatial Planning, Niet-EER: [[3.8114824]] => [[0.8114824]]
# M Taalwetenschappen, EER: [[6.647396]] => [[0.6473961]]
# M Taalwetenschappen, NL: [[27.679813]] => [[14.320187]]
# M Taalwetenschappen, Niet-EER: [[3.403121]] => [[2.403121]]
# M Tandheelkunde, EER: [[4.0606437]] => [[1.9393563]]
# M Tandheelkunde, NL: [[128.72655]] => [[27.273453]]
# M Theologie, NL: [[5.1243067]] => [[0.12430668]]
# [W 2024-05-14 11:36:09,902] Trial 1 failed with parameters: {'look_back': 2, 'nr_of_epochs': 40} because of the following error: The value None could not be cast to float..
# [W 2024-05-14 11:36:09,902] Trial 1 failed with value None.
# M Business Administration, EER: [[9.490413]] => [[4.5095873]]
# M Business Administration, NL: [[33.140167]] => [[139.85983]]
# M Business Administration, Niet-EER: [[3.4694977]] => [[0.5305023]]
# M Cognitive Neuroscience (research), EER: [[26.57737]] => [[19.42263]]
# M Cognitive Neuroscience (research), NL: [[7.4055614]] => [[39.594437]]
# M Cognitive Neuroscience (research), Niet-EER: [[1.8548769]] => [[14.1451235]]
# M Communicatie- & informatiewetenschappen, EER: [[0.9899267]] => [[1.0100733]]
# M Communicatie- & informatiewetenschappen, NL: [[44.636276]] => [[9.636276]]
# M Communicatiewetenschap, NL: [[15.361095]] => [[20.638905]]
# M Computing Science, EER: [[14.344981]] => [[30.655018]]
# M Computing Science, NL: [[76.40475]] => [[135.59525]]
# M Computing Science, Niet-EER: [[5.8972106]] => [[11.102789]]
# M Economics, EER: [[9.270862]] => [[5.2708616]]
# M Economics, NL: [[48.86477]] => [[6.135231]]
# M Economics, Niet-EER: [[4.039759]] => [[3.0397592]]
# M Educatie in de Mens- en Maatschappijwetenschappen, NL: [[4.89807]] => [[23.10193]]
# M Educatie in de Taal- en cultuurwetenschappen, NL: [[6.1514406]] => [[29.84856]]
# M Environment and Society Studies, EER: [[9.983598]] => [[0.01640224]]
# M Environment and Society Studies, NL: [[36.452236]] => [[5.547764]]
# M Europese Studies (joint degree), EER: [[1.935134]] => [[1.064866]]
# M Europese Studies (joint degree), NL: [[9.26022]] => [[2.2602196]]
# M Filosofie, EER: [[0.2711075]] => [[1.7288926]]
# M Filosofie, NL: [[65.7171]] => [[17.282898]]
# M Filosofie, Niet-EER: [[0.08637784]] => [[0.91362214]]
# M Filosofie (research), EER: [[5.903616]] => [[0.09638405]]
# M Filosofie (research), NL: [[15.263324]] => [[13.736676]]
# M Filosofie (research), Niet-EER: [[2.194781]] => [[2.805219]]
# M Fiscaal Recht, NL: [[71.92856]] => [[1.9285583]]
# M Geneeskunde, EER: [[7.759851]] => [[4.240149]]
# M Geneeskunde, NL: [[795.0165]] => [[99.98352]]
# M Geschiedenis, NL: [[22.410755]] => [[14.589245]]
# M Historical, Literary and Cultural Studies (research), EER: [[0.34789166]] => [[0.6521083]]
# M Historical, Literary and Cultural Studies (research), NL: [[10.378797]] => [[10.621203]]
# M Historical, Literary and Cultural Studies (research), Niet-EER: [[0.6210102]] => [[0.37898982]]
# M Human Geography, EER: [[17.328035]] => [[2.6719646]]
# M Human Geography, NL: [[100.644684]] => [[10.644684]]
# M Human Geography, Niet-EER: [[2.2819755]] => [[0.7180245]]
# M Information Sciences, NL: [[30.97776]] => [[6.9777603]]
# M International and European Law, EER: [[6.0245194]] => [[10.975481]]
# M International and European Law, NL: [[34.131233]] => [[8.131233]]
# M International and European Law, Niet-EER: [[2.085621]] => [[1.9143789]]
# M Kunst- & cultuurwetenschappen, EER: [[8.579927]] => [[2.5799274]]
# M Kunst- & cultuurwetenschappen, NL: [[38.704838]] => [[2.2951622]]
# M Kunst- & cultuurwetenschappen, Niet-EER: [[0.23771341]] => [[0.7622866]]
# M Leraar Voorbereidend Hoger Onderwijs in de Bètawetenschappen, NL: [[1.9796025]] => [[2.0203977]]
# M Leraar Voorbereidend Hoger Onderwijs in de Mens- en Maatschappijwetenschappen, NL: [[3.3963284]] => [[1.6036716]]
# M Leraar Voorbereidend Hoger Onderwijs in de Taal en Cultuurwetenschappen, NL: [[2.2084475]] => [[2.7915525]]
# M Letterkunde, NL: [[23.59288]] => [[14.40712]]
# M Linguistics and Communication Sciences (research), EER: [[0.31769252]] => [[5.6823072]]
# M Linguistics and Communication Sciences (research), NL: [[-0.16178389]] => [[9.161784]]
# M Linguistics and Communication Sciences (research), Niet-EER: [[1.6817708]] => [[3.3182292]]
# M Mathematics, EER: [[-0.09296361]] => [[2.0929637]]
# M Mathematics, NL: [[26.992945]] => [[22.007055]]
# M Medical Biology, EER: [[34.127033]] => [[4.872967]]
# M Medical Biology, NL: [[60.139454]] => [[208.86055]]
# M Medical Biology, Niet-EER: [[1.7273278]] => [[8.272673]]
# M Molecular Mechanisms of Disease (research), EER: [[4.3906813]] => [[5.6093187]]
# M Molecular Mechanisms of Disease (research), NL: [[12.774303]] => [[5.2256966]]
# M Molecular Mechanisms of Disease (research), Niet-EER: [[2.5456405]] => [[2.4543595]]
# M Molecular Sciences, EER: [[16.632027]] => [[2.3679733]]
# M Molecular Sciences, NL: [[117.72141]] => [[15.278587]]
# M Molecular Sciences, Niet-EER: [[3.245121]] => [[1.245121]]
# M Nederlands Recht, NL: [[494.721]] => [[106.27899]]
# M Noord-Amerika Studies, NL: [[12.865101]] => [[8.865101]]
# M Notarieel Recht, NL: [[45.92878]] => [[24.07122]]
# M Onderneming en Recht (research), NL: [[6.3624077]] => [[2.6375923]]
# M Onderwijswetenschappen, NL: [[19.904963]] => [[28.095037]]
# M Oudheidstudies, NL: [[5.697364]] => [[1.3026361]]
# M Pedagogische Wetenschappen, NL: [[236.01517]] => [[19.984833]]
# M Physics and Astronomy, EER: [[8.172815]] => [[12.827185]]
# M Physics and Astronomy, NL: [[45.000153]] => [[74.99985]]
# M Physics and Astronomy, Niet-EER: [[0.40943795]] => [[7.590562]]
# M Political Science, EER: [[4.384666]] => [[1.384666]]
# M Political Science, NL: [[33.4677]] => [[36.5323]]
# M Political Science, Niet-EER: [[0.5015621]] => [[0.49843788]]
# M Psychologie, EER: [[21.33255]] => [[4.33255]]
# M Psychologie, NL: [[70.57998]] => [[67.42002]]
# M Psychologie, Niet-EER: [[0.06638837]] => [[0.93361163]]
# M Social and Cultural Science: Comparative Research on Societies (research), EER: [[0.68626666]] => [[2.3137333]]
# M Social and Cultural Science: Comparative Research on Societies (research), NL: [[10.414001]] => [[2.4140015]]
# M Sociologie, NL: [[2.9458172]] => [[6.054183]]
# M Spatial Planning, EER: [[3.750532]] => [[7.249468]]
# M Spatial Planning, NL: [[22.891117]] => [[60.108883]]
# M Spatial Planning, Niet-EER: [[3.3055356]] => [[0.30553555]]
# M Taalwetenschappen, EER: [[3.6847816]] => [[2.3152184]]
# M Taalwetenschappen, NL: [[38.306046]] => [[3.6939545]]
# M Taalwetenschappen, Niet-EER: [[1.7309661]] => [[0.7309661]]
# M Tandheelkunde, EER: [[3.517301]] => [[2.482699]]
# M Tandheelkunde, NL: [[129.91557]] => [[26.084427]]
# M Theologie, NL: [[4.708481]] => [[0.29151917]]
# [W 2024-05-14 11:47:35,663] Trial 2 failed with parameters: {'look_back': 6, 'nr_of_epochs': 25} because of the following error: The value None could not be cast to float..
# [W 2024-05-14 11:47:35,664] Trial 2 failed with value None.
# M Theologie & Religiewetenschappen, NL: [[26.91066]] => [[114.08934]]
# Final MAE: [[32.2958]]
# 32.2958
# B Algemene Cultuurwetenschappen, EER: [[9.050674]] => [[26.949326]]
# B Algemene Cultuurwetenschappen, NL: [[52.157158]] => [[24.842842]]
# B Algemene Cultuurwetenschappen, Niet-EER: [[2.2157857]] => [[6.784214]]
# B Artificial Intelligence, EER: [[67.650154]] => [[16.349846]]
# B Artificial Intelligence, NL: [[246.36658]] => [[28.633423]]
# B Artificial Intelligence, Niet-EER: [[12.09456]] => [[3.9054403]]
# B Bedrijfskunde, EER: [[19.113785]] => [[60.886215]]
# B Bedrijfskunde, NL: [[131.47365]] => [[883.52637]]
# B Bedrijfskunde, Niet-EER: [[18.949327]] => [[0.94932747]]
# B Bestuurskunde, NL: [[260.47]] => [[66.47]]
# B Biology, EER: [[40.887333]] => [[83.11267]]
# B Biology, NL: [[231.16536]] => [[9.8346405]]
# B Biology, Niet-EER: [[7.952628]] => [[15.047372]]
# B Biomedische Wetenschappen, NL: [[182.8302]] => [[11.1698]]
# B Chemistry, EER: [[3.7017515]] => [[21.298248]]
# B Chemistry, NL: [[59.05855]] => [[17.941448]]
# B Chemistry, Niet-EER: [[4.02298]] => [[5.97702]]
# B Communicatie- en Informatiewetenschappen, EER: [[37.61061]] => [[8.389389]]
# B Communicatie- en Informatiewetenschappen, NL: [[162.42586]] => [[43.574142]]
# B Communicatie- en Informatiewetenschappen, Niet-EER: [[8.218623]] => [[2.2186232]]
# B Communicatiewetenschap, NL: [[29.89582]] => [[195.10419]]
# B Computing Science, EER: [[26.209671]] => [[71.79033]]
# B Computing Science, NL: [[307.69455]] => [[37.30545]]
# B Computing Science, Niet-EER: [[4.2322764]] => [[20.767723]]
# B Culturele Antropologie en Ontwikkelingssociologie, NL: [[84.290886]] => [[28.709114]]
# B Duitse Taal en Cultuur, NL: [[23.222076]] => [[6.2220764]]
# B Economie en Bedrijfseconomie, EER: [[13.666108]] => [[14.333892]]
# B Economie en Bedrijfseconomie, NL: [[283.56387]] => [[95.43613]]
# B Economie en Bedrijfseconomie, Niet-EER: [[10.578457]] => [[3.4215431]]
# B English Language and Culture, EER: [[6.6005564]] => [[11.399444]]
# B English Language and Culture, NL: [[60.741085]] => [[103.25891]]
# B English Language and Culture, Niet-EER: [[0.7926314]] => [[1.2073686]]
# B European Law School, EER: [[0.3319205]] => [[1.6680795]]
# B European Law School, NL: [[53.98337]] => [[93.01663]]
# B Filosofie, EER: [[4.5549793]] => [[52.445023]]
# M Information Sciences, NL: [[22.907158]] => [[1.0928421]]
# M International and European Law, EER: [[5.660623]] => [[11.339376]]
# M International and European Law, NL: [[5.953226]] => [[20.046774]]
# M International and European Law, Niet-EER: [[5.031088]] => [[1.0310879]]
# M Kunst- & cultuurwetenschappen, EER: [[7.9753957]] => [[1.9753957]]
# M Kunst- & cultuurwetenschappen, NL: [[28.285105]] => [[12.714895]]
# M Kunst- & cultuurwetenschappen, Niet-EER: [[2.1636202]] => [[1.1636202]]
# M Leraar Voorbereidend Hoger Onderwijs in de Bètawetenschappen, NL: [[1.0067203]] => [[2.9932797]]
# M Leraar Voorbereidend Hoger Onderwijs in de Mens- en Maatschappijwetenschappen, NL: [[2.2183816]] => [[2.7816184]]
# M Leraar Voorbereidend Hoger Onderwijs in de Taal en Cultuurwetenschappen, NL: [[3.2523105]] => [[1.7476895]]
# M Letterkunde, NL: [[19.419733]] => [[18.580267]]
# M Linguistics and Communication Sciences (research), EER: [[0.54555625]] => [[5.454444]]
# M Linguistics and Communication Sciences (research), NL: [[4.121705]] => [[4.878295]]
# M Linguistics and Communication Sciences (research), Niet-EER: [[5.125069]] => [[0.12506914]]
# M Mathematics, EER: [[-0.11731455]] => [[2.1173146]]
# M Mathematics, NL: [[41.771297]] => [[7.2287025]]
# M Medical Biology, EER: [[31.94791]] => [[7.0520897]]
# M Medical Biology, NL: [[140.00403]] => [[128.99597]]
# M Medical Biology, Niet-EER: [[3.8993955]] => [[6.1006045]]
# M Molecular Mechanisms of Disease (research), EER: [[5.0823345]] => [[4.9176655]]
# M Molecular Mechanisms of Disease (research), NL: [[14.711418]] => [[3.2885818]]
# M Molecular Mechanisms of Disease (research), Niet-EER: [[4.393657]] => [[0.6063428]]
# M Molecular Sciences, EER: [[18.505274]] => [[0.49472618]]
# M Molecular Sciences, NL: [[132.125]] => [[0.875]]
# M Molecular Sciences, Niet-EER: [[3.5414715]] => [[1.5414715]]
# M Nederlands Recht, NL: [[530.2393]] => [[70.76068]]
# M Noord-Amerika Studies, NL: [[8.7565565]] => [[4.7565565]]
# M Notarieel Recht, NL: [[28.475962]] => [[41.52404]]
# M Onderneming en Recht (research), NL: [[2.7318468]] => [[6.268153]]
# M Onderwijswetenschappen, NL: [[37.944298]] => [[10.055702]]
# M Oudheidstudies, NL: [[6.42591]] => [[0.57409]]
# M Pedagogische Wetenschappen, NL: [[48.44104]] => [[207.55896]]
# M Physics and Astronomy, EER: [[3.2986689]] => [[17.701332]]
# M Physics and Astronomy, NL: [[70.620926]] => [[49.379074]]
# M Physics and Astronomy, Niet-EER: [[2.2084846]] => [[5.7915154]]
# M Political Science, EER: [[3.4761658]] => [[0.47616577]]
# M Political Science, NL: [[45.662216]] => [[24.337784]]
# M Political Science, Niet-EER: [[0.52346736]] => [[0.47653264]]
# M Psychologie, EER: [[29.904087]] => [[12.904087]]
# M Psychologie, NL: [[88.89591]] => [[49.104088]]
# M Psychologie, Niet-EER: [[0.19477214]] => [[0.8052279]]
# M Social and Cultural Science: Comparative Research on Societies (research), EER: [[0.454303]] => [[2.545697]]
# M Social and Cultural Science: Comparative Research on Societies (research), NL: [[8.647666]] => [[0.647666]]
# M Sociologie, NL: [[5.8006115]] => [[3.1993885]]
# M Spatial Planning, EER: [[2.9891608]] => [[8.010839]]
# M Spatial Planning, NL: [[34.957195]] => [[48.042805]]
# M Spatial Planning, Niet-EER: [[2.1038754]] => [[0.8961246]]
# M Taalwetenschappen, EER: [[6.2303123]] => [[0.23031235]]
# M Taalwetenschappen, NL: [[17.834393]] => [[24.165607]]
# M Taalwetenschappen, Niet-EER: [[1.1547949]] => [[0.15479493]]
# M Tandheelkunde, EER: [[1.6363384]] => [[4.363662]]
# M Tandheelkunde, NL: [[39.110767]] => [[116.88924]]
# M Theologie, NL: [[3.4557562]] => [[1.5442438]]
# [W 2024-05-14 11:58:30,467] Trial 3 failed with parameters: {'look_back': 8, 'nr_of_epochs': 36} because of the following error: The value None could not be cast to float..
# [W 2024-05-14 11:58:30,482] Trial 3 failed with value None.
# M Theologie & Religiewetenschappen, NL: [[83.84917]] => [[57.150833]]
# Final MAE: [[42.850437]]
# 42.850437
# B Algemene Cultuurwetenschappen, EER: [[5.5107155]] => [[30.489285]]
# B Algemene Cultuurwetenschappen, NL: [[25.376623]] => [[51.623375]]
# B Algemene Cultuurwetenschappen, Niet-EER: [[3.4976304]] => [[5.50237]]
# B Artificial Intelligence, EER: [[5.111751]] => [[78.88825]]
# B Artificial Intelligence, NL: [[43.675945]] => [[231.32405]]
# B Artificial Intelligence, Niet-EER: [[16.044313]] => [[0.04431343]]
# B Bedrijfskunde, EER: [[21.685724]] => [[58.314278]]
# ...
#     664     name,
# --> 665     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     666     args, {},
#     667     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     668                                        maximum_iterations, while_op,
#     669                                        body_graph_inputs, body_graph_outputs))
#     671 # Update the list of outputs with tensors corresponding to the captured
#     672 # tensors. We capture 3 types of tensors when building the grad fn:
#     673 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     676 # 2. Resources, which are output as is.
#     677 # 3. Forward graph loop invariants, which are output as is.
#     678 for external_capture, internal_capture in grad_func_graph.captures:
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\while_v2.py:720, in _grad_fn(ys, xs, args, func_graph)
#     713 grad_ys = args[3:]
#     715 # Build the gradient graph. Note that this builds the gradient computation of
#     716 # func_graph in the current graph, which requires capturing tensors from
#     717 # func_graph. The captured func_graph tensors are resolved to external tensors
#     718 # after the forward While op has been rewritten in _resolve_grad_captures.
#     719 # TODO(srbs): Mark GradientsHelper as public?
# --> 720 grad_outs = gradients_util._GradientsHelper(
#     721     ys, xs, grad_ys=grad_ys, src_graph=func_graph,
#     722     unconnected_gradients="zero")
#     724 # TODO(b/118712257): Handle the case when grad_outs has None's e.g. when there
#     725 # is a tf.StopGradient in the loop body.
#     726 assert all(g is not None for g in grad_outs)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\gradients_util.py:733, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
# --> 733     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\gradients_util.py:365, in _MaybeCompile(scope, op, func, grad_fn)
#     362     xla_compile = False
#     364 if not xla_compile:
# --> 365   return grad_fn()  # Exit early
#     367 # If the gradients are supposed to be compiled separately, we give them a
#     368 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     369 # they just inherit the existing _XlaScope name, which lets them be merged
#     370 # together with the non-gradient computation.
#     371 if xla_separate_compiled_gradients:
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\gradients_util.py:734, in _GradientsHelper.<locals>.<lambda>()
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
#     733     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\list_ops.py:297, in _TensorListSetItemGrad(op, dlist)
#     294 """Gradient function for TensorListSetItem."""
#     295 input_list, index, item = op.inputs
#     296 list_grad = gen_list_ops.tensor_list_set_item(
# --> 297     dlist, index=index, item=array_ops.zeros_like(item)
#     298 )
#     299 index_grad = None
#     300 element_grad = tensor_list_get_item(
#     301     dlist,
#     302     index,
#     303     element_shape=array_ops.shape(item),
#     304     element_dtype=item.dtype,
#     305 )
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2664, in zeros_like(tensor, dtype, name, optimize)
#    2627 @tf_export(v1=["zeros_like"])
#    2628 @dispatch.register_unary_elementwise_api
#    2629 @dispatch.add_dispatch_support
#    2630 def zeros_like(tensor, dtype=None, name=None, optimize=True):
#    2631   """Creates a tensor with all elements set to zero.
#    2632
#    2633   See also `tf.zeros`.
#    (...)
#    2662     A `Tensor` with all elements set to zero.
#    2663   """
# -> 2664   return zeros_like_impl(tensor, dtype, name, optimize)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2558, in _tag_zeros_tensor.<locals>.wrapped(*args, **kwargs)
#    2557 def wrapped(*args, **kwargs):
# -> 2558   tensor = fun(*args, **kwargs)
#    2559   tensor._is_zeros_tensor = True
#    2560   return tensor
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2770, in zeros_like_impl(tensor, dtype, name, optimize, layout)
#    2768 """Internal implementation for the v1/v2 zeros_like API calls."""
#    2769 with ops.name_scope(name, "zeros_like", [tensor]) as name:
# -> 2770   return array_like_impl(
#    2771       zeros,
#    2772       gen_array_ops.zeros_like,
#    2773       tensor,
#    2774       dtype,
#    2775       name,
#    2776       optimize=optimize,
#    2777       layout=layout,
#    2778   )
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2752, in array_like_impl(array_fn, array_like_fn, tensor, dtype, name, optimize, layout)
#    2742 # For now, variant types must be created via array_like_fn; as we need to
#    2743 # pass the input variant object to the proper array_fn callback.
#    2745 if (
#    2746     optimize
#    2747     and tensor_shape.is_fully_defined()
#    (...)
#    2750   # We can produce a result tensor independent of the value of 'tensor',
#    2751   # since the shape is known statically.
# -> 2752   return array_fn(
#    2753       tensor_shape, dtype=dtype or tensor_dtype, name=name, layout=layout
#    2754   )
#    2756 if dtype is not None and dtype != tensor_dtype and dtype != dtypes.variant:
#    2757   return array_fn(
#    2758       shape_internal(tensor, optimize=optimize),
#    2759       dtype=dtype,
#    2760       name=name,
#    2761       layout=layout,
#    2762   )
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2558, in _tag_zeros_tensor.<locals>.wrapped(*args, **kwargs)
#    2557 def wrapped(*args, **kwargs):
# -> 2558   tensor = fun(*args, **kwargs)
#    2559   tensor._is_zeros_tensor = True
#    2560   return tensor
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2610, in zeros(shape, dtype, name, layout)
#    2606 try:
#    2607   if not context.executing_eagerly():
#    2608     # Create a constant if it won't be very big. Otherwise, create a fill
#    2609     # op to prevent serialized GraphDefs from becoming too large.
# -> 2610     output = _constant_if_small(zero, shape, dtype, name, layout=layout)
#    2611     if output is not None:
#    2612       return output
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\array_ops.py:2542, in _constant_if_small(value, shape, dtype, name, layout)
#    2540 try:
#    2541   if np.prod(shape) < 1000:
# -> 2542     return d_api.call_with_layout(
#    2543         constant, layout, value, shape=shape, dtype=dtype, name=name
#    2544     )
#    2545 except (NotImplementedError, TypeError):
#    2546   # Happens when shape is a Tensor, list with Tensor elements, etc.
#    2547   pass
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\dtensor\python\api.py:64, in call_with_layout(fn, layout, *args, **kwargs)
#      62   else:
#      63     return relayout(fn(*args, **kwargs), layout)
# ---> 64 return fn(*args, **kwargs)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:281, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     279 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     280 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 281 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     282     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     284 if op_callbacks.should_invoke_op_callbacks():
#     285   # TODO(b/147670703): Once the special-op creation code paths
#     286   # are unified. Remove this `if` block.
#     287   callback_outputs = op_callbacks.invoke_op_callbacks(
#     288       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\ops\while_v2.py:1011, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     994 if (op_type in optimized_reduction_ops and
#     995     not util.output_all_intermediates() and
#     996     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#     999     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1000         self._forward_graph)):
#    1001   return self._move_op_to_forward_graph(
#    1002       op_type,
#    1003       inputs,
#    (...)
#    1008       op_def=op_def,
#    1009       compute_device=compute_device)
# -> 1011 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1012     op_type,
#    1013     inputs,
#    1014     dtypes=dtypes,
#    1015     input_types=input_types,
#    1016     name=name,
#    1017     attrs=attrs,
#    1018     op_def=op_def,
#    1019     compute_device=compute_device)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2682, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2679 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2680 # Session.run call cannot occur between creating and mutating the op.
#    2681 with self._mutation_lock():
# -> 2682   ret = Operation.from_node_def(
#    2683       node_def,
#    2684       self,
#    2685       inputs=inputs,
#    2686       output_types=dtypes,
#    2687       control_inputs=control_inputs,
#    2688       input_types=input_types,
#    2689       original_op=self._default_original_op,
#    2690       op_def=op_def,
#    2691   )
#    2692   self._create_op_helper(ret, compute_device=compute_device)
#    2693 return ret
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1177, in Operation.from_node_def(***failed resolving arguments***)
#    1174     control_input_ops.append(control_op)
#    1176 # Initialize c_op from node_def and other inputs
# -> 1177 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1178 self = Operation(c_op, SymbolicTensor)
#    1179 self._init(g)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jjble\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1034, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1030   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1031                                          serialized)
#    1033 try:
# -> 1034   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1035 except errors.InvalidArgumentError as e:
#    1036   # Convert to ValueError for backwards compatibility.
#    1037   raise ValueError(e.message)
#
# KeyboardInterrupt:
