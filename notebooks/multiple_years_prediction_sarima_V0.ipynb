# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from scripts.load_data import *
from scripts.availabledata import *
from scripts.individual import *
from scripts.cumulative import *
from scripts.bothdatasets import *
from scripts.dataoption import *
from scripts.higher_years import *

# %%
configuration = load_configuration("../configuration/configuration.json")

data_individual, data_cumulative, data_student_numbers_first_years, data_student_numbers_higher_years, data_student_numbers_volume, data_latest, data_distances, ensemble_weights = load_data(configuration, StudentYearPrediction.FIRST_YEARS)

dataholder = Cumulative(data_cumulative, data_student_numbers_first_years, configuration)

data_cumulative = dataholder.preprocess()

numerus_fixus_list = configuration["numerus_fixus"]
# Out:
# c:\Users\jjble\Documents\Master\Jaar2_Semester2\Research_Internship\Tijdens\Code\studentprognose\scripts\load_data.py:11: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_cumulative = pd.read_csv(paths["path_cumulative"], sep=';', skiprows=[1]) if (paths["path_cumulative"] != "" and os.path.exists(paths["path_cumulative"])) else None
# c:\Users\jjble\Documents\Master\Jaar2_Semester2\Research_Internship\Tijdens\Code\studentprognose\scripts\cumulative.py:72: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data[key] = data[key].str.replace('.', '')

# %%
predict_year = 2023
skip_years = 1
predict_week = 15

# %%
data_to_predict = data_cumulative[(data_cumulative["Collegejaar"] == predict_year - skip_years) &
                                               (data_cumulative["Weeknummer"] == predict_week)]

dataholder.prepare_data()

# %%
def predict_with_xgboost(data, programme, examtype, herkomst, predict_year, skip_years=0):
    try:
        # Train/test split
        if programme not in numerus_fixus_list:
            train = data[(data["Collegejaar"] < predict_year - skip_years) & (data["Examentype"] == examtype) & (
                ~data['Croho groepeernaam'].isin(numerus_fixus_list))]
        elif programme in numerus_fixus_list:
            train = data[(data["Collegejaar"] < predict_year - skip_years) & (data['Croho groepeernaam'] == programme)]

        test = data[(data["Collegejaar"] == predict_year) & (data['Croho groepeernaam'] == programme) & (data["Herkomst"] == herkomst)]

        if data_student_numbers_first_years is not None:
            train = train.merge(data_student_numbers_first_years[['Croho groepeernaam', 'Collegejaar', 'Herkomst', 'Aantal_studenten']],
                                on=['Croho groepeernaam', 'Collegejaar', 'Herkomst'])
        else:
            # Student count is required
            return np.nan

        train = train.drop_duplicates()

        X_train = train.drop(['Aantal_studenten'], axis=1)
        y_train = train.pop('Aantal_studenten')

        # Encode
        # Specify the numeric and categorical column names
        numeric_cols = ['Collegejaar'] + [str(x) for x in get_weeks_list(38)]
        categorical_cols = ['Examentype', 'Faculteit', 'Croho groepeernaam', 'Herkomst']

        # Create transformers for numeric and categorical columns
        numeric_transformer = "passthrough"  # No transformation for numeric columns
        categorical_transformer = OneHotEncoder(handle_unknown='ignore')

        # Create the column transformer
        preprocessor = ColumnTransformer(
            transformers=[
                ('numeric', numeric_transformer, numeric_cols),
                ('categorical', categorical_transformer, categorical_cols)
            ])

        # Apply the preprocessing to the training and test data
        X_train = preprocessor.fit_transform(X_train)
        test = preprocessor.transform(test)
        # Model
        model = XGBRegressor(learning_rate=0.25)

        model.fit(X_train, y_train)

        predictie = model.predict(test)

        return int(round(predictie[0], 0))
    except ValueError:
        print(f"Cumulative xgboost error on: {programme}, {herkomst}")
        return np.nan

# %%
data_count = data_student_numbers_first_years.copy()

# %%
data = dataholder.data_cumulative.copy()

data = data.drop_duplicates()

data = data[data["Collegejaar"] >= 2016]

full_data = transform_data(data, 'ts')

total_mae = 0.0
total_mape = 0.0
count = 0.0

for _, row in data_to_predict.iterrows():
    programme = row['Croho groepeernaam']
    herkomst = row["Herkomst"]
    examtype = row["Examentype"]

    gc.collect()

    data = full_data.copy()

    data = data[data["Herkomst"] == herkomst]

    data = data[data["Collegejaar"] <= predict_year - skip_years]

    data = data[data['Croho groepeernaam'] == programme]

    if int(predict_week) > 38:
        pred_len = 38 + 52 - int(predict_week)
    else:
        pred_len = 38 - int(predict_week)

    previous_pred_len = pred_len
    pred_len += 52

    # Week 39 to 0
    data['39'] = 0
    full_data['39'] = 0

    def create_time_series(data: pd.DataFrame, pred_len: int) -> np.array:
        """
        Create a time series data array from a DataFrame for a given prediction length.

        Args:
            data (pd.DataFrame): The input DataFrame containing time series data.
            pred_len (int): The length of the time series to be created.

        Returns:
            np.ndarray: A NumPy array containing the time series data.
        """

        ts_data = data.loc[:, get_all_weeks_valid(data.columns)].values.flatten()
        ts_data = ts_data[:-pred_len]

        return np.array(ts_data)

    ts_data = create_time_series(data, pred_len)
    # if predict_week == 38:
    #     prediction = _predict_with_xgboost(full_data, programme, examtype, herkomst)
    #     return prediction

    try:
        model = sm.tsa.statespace.SARIMAX(ts_data, order=(1, 0, 1), seasonal_order=(1, 1, 1, 52))
        results = model.fit(disp=0)

        pred = results.forecast(steps=pred_len)

        index = str(increment_week(predict_week))

        full_data.loc[
        (full_data["Collegejaar"] == predict_year - skip_years) & (full_data['Croho groepeernaam'] == programme) & (full_data["Herkomst"] == herkomst),
        index:'38'] = pred[:previous_pred_len]

        full_data.loc[
        (full_data["Collegejaar"] == predict_year) & (full_data['Croho groepeernaam'] == programme) & (full_data["Herkomst"] == herkomst),
        '39':'38'] = pred[-52:]

        # prediction = _predict_with_xgboost(full_data, programme, examtype, herkomst)
        # return prediction, pred

        prediction_first_year = predict_with_xgboost(full_data, programme, examtype, herkomst, predict_year - skip_years)

        data_count.loc[(data_count["Collegejaar"] == predict_year - skip_years) &
                       (data_count["Croho groepeernaam"] == programme) &
                       (data_count["Herkomst"] == herkomst), "Aantal_studenten"] = prediction_first_year

        final_prediction = predict_with_xgboost(full_data, programme, examtype, herkomst, predict_year, skip_years)

        nr_of_students = data_student_numbers_first_years[(data_student_numbers_first_years["Collegejaar"] == predict_year) & (data_student_numbers_first_years["Croho groepeernaam"] == programme) & 
                                                          (data_student_numbers_first_years["Herkomst"] == herkomst)]["Aantal_studenten"]

        mae = "???"
        mape = "???"
        if len(nr_of_students) > 0:
            mae = abs(nr_of_students.iloc[0] - final_prediction)
            mape = abs((nr_of_students.iloc[0] - final_prediction) / nr_of_students.iloc[0])

            total_mae += mae
            total_mape += mape
            count += 1.0

        print(f"{programme}, {herkomst}, {final_prediction}, MAE: {mae}, MAPE: {mape}")

    except (LA.LinAlgError, IndexError, ValueError) as error:
        print(f"Cumulative sarima error on: {programme}, {herkomst}")
        print(error)

print(f"Final MAE: {total_mae / count}")
print(f"Final MAPE: {total_mape / count}")

full_data.to_excel("full_data.xlsx", index=False)
data_count.to_excel("data_count.xlsx", index=False)
# Out:
# B Algemene Cultuurwetenschappen, EER, 16, MAE: 2, MAPE: 0.14285714285714285
# B Algemene Cultuurwetenschappen, NL, 30, MAE: 1, MAPE: 0.034482758620689655
# B Algemene Cultuurwetenschappen, Niet-EER, 5, MAE: 1, MAPE: 0.25
# B Artificial Intelligence, EER, 30, MAE: 17, MAPE: 0.3617021276595745
# B Artificial Intelligence, NL, 120, MAE: 33, MAPE: 0.21568627450980393
# B Artificial Intelligence, Niet-EER, 9, MAE: 6, MAPE: 0.4
# B Artificial Intelligence, onbekend, 4, MAE: ???, MAPE: ???
# B Bedrijfskunde, EER, 19, MAE: 10, MAPE: 0.3448275862068966
# B Bedrijfskunde, NL, 366, MAE: 15, MAPE: 0.03937007874015748
# B Bedrijfskunde, Niet-EER, 18, MAE: 7, MAPE: 0.6363636363636364
# B Bestuurskunde, NL, 80, MAE: 3, MAPE: 0.03614457831325301
# B Biology, EER, 160, MAE: 112, MAPE: 2.3333333333333335
# B Biology, NL, 64, MAE: 26, MAPE: 0.28888888888888886
# B Biology, Niet-EER, 29, MAE: 24, MAPE: 4.8
# B Biomedische Wetenschappen, EER, 1, MAE: ???, MAPE: ???
# B Biomedische Wetenschappen, NL, 98, MAE: 3, MAPE: 0.031578947368421054
# B Biomedische Wetenschappen, Niet-EER, 1, MAE: 1, MAPE: 0.5
# Cumulative xgboost error on: B Biomedische Wetenschappen, onbekend
# B Biomedische Wetenschappen, onbekend, nan, MAE: ???, MAPE: ???
# B Chemistry, EER, 11, MAE: 4, MAPE: 0.5714285714285714
# B Chemistry, NL, 43, MAE: 15, MAPE: 0.5357142857142857
# B Chemistry, Niet-EER, 5, MAE: 3, MAPE: 1.5
# B Communicatie- en Informatiewetenschappen, EER, 36, MAE: 18, MAPE: 1.0
# B Communicatie- en Informatiewetenschappen, NL, 87, MAE: 20, MAPE: 0.29850746268656714
# B Communicatie- en Informatiewetenschappen, Niet-EER, 6, MAE: 4, MAPE: 2.0
# Cumulative xgboost error on: B Communicatie- en Informatiewetenschappen, onbekend
# B Communicatie- en Informatiewetenschappen, onbekend, nan, MAE: ???, MAPE: ???
# B Communicatiewetenschap, NL, 71, MAE: 33, MAPE: 0.3173076923076923
# B Computing Science, EER, 78, MAE: 19, MAPE: 0.3220338983050847
# B Computing Science, NL, 116, MAE: 35, MAPE: 0.43209876543209874
# B Computing Science, Niet-EER, 12, MAE: 11, MAPE: 0.4782608695652174
# B Culturele Antropologie en Ontwikkelingssociologie, NL, 43, MAE: 18, MAPE: 0.29508196721311475
# B Duitse Taal en Cultuur, NL, 14, MAE: 5, MAPE: 0.5555555555555556
# B Duitse Taal en Cultuur, Niet-EER, 1, MAE: ???, MAPE: ???
# B Economie en Bedrijfseconomie, EER, 18, MAE: 1, MAPE: 0.05263157894736842
# B Economie en Bedrijfseconomie, NL, 180, MAE: 40, MAPE: 0.2857142857142857
# B Economie en Bedrijfseconomie, Niet-EER, 4, MAE: 3, MAPE: 0.42857142857142855
# M Business Administration, NL, 280, MAE: 37, MAPE: 0.1167192429022082
# M Business Administration, Niet-EER, 11, MAE: 6, MAPE: 1.2
# M Cognitive Neuroscience (research), EER, 21, MAE: 15, MAPE: 0.4166666666666667
# M Cognitive Neuroscience (research), NL, 24, MAE: 3, MAPE: 0.1111111111111111
# M Cognitive Neuroscience (research), Niet-EER, 8, MAE: 4, MAPE: 0.3333333333333333
# M Communicatie- & informatiewetenschappen, EER, 6, MAE: 1, MAPE: 0.2
# M Communicatie- & informatiewetenschappen, NL, 84, MAE: 10, MAPE: 0.13513513513513514
# M Communicatie- & informatiewetenschappen, Niet-EER, 3, MAE: ???, MAPE: ???
# Cumulative xgboost error on: M Communicatie- & informatiewetenschappen, onbekend
# M Communicatie- & informatiewetenschappen, onbekend, nan, MAE: ???, MAPE: ???
# M Communicatiewetenschap, NL, 78, MAE: 10, MAPE: 0.14705882352941177
# M Computing Science, EER, 8, MAE: 12, MAPE: 0.6
# M Computing Science, NL, 68, MAE: 19, MAPE: 0.3877551020408163
# M Computing Science, Niet-EER, 9, MAE: 2, MAPE: 0.18181818181818182
# Cumulative xgboost error on: M Computing Science, onbekend
# M Computing Science, onbekend, nan, MAE: ???, MAPE: ???
# Cumulative sarima error on: M Curriculumontwikkeling voor Primair Onderwijs, NL
# Schur decomposition solver error.
# M Economics, EER, 17, MAE: 12, MAPE: 2.4
# M Economics, NL, 99, MAE: 8, MAPE: 0.07476635514018691
# M Economics, Niet-EER, 7, MAE: 6, MAPE: 6.0
# Cumulative xgboost error on: M Educatie in de Mens- en Maatschappijwetenschappen, EER
# M Educatie in de Mens- en Maatschappijwetenschappen, EER, nan, MAE: ???, MAPE: ???
# M Educatie in de Mens- en Maatschappijwetenschappen, NL, 8, MAE: 13, MAPE: 0.6190476190476191
# M Educatie in de Mens- en Maatschappijwetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# Cumulative xgboost error on: M Educatie in de Taal- en Cultuurwetenschappen, EER
# M Educatie in de Taal- en Cultuurwetenschappen, EER, nan, MAE: ???, MAPE: ???
# M Educatie in de Taal- en Cultuurwetenschappen, NL, 11, MAE: ???, MAPE: ???
# M Educatie in de Taal- en Cultuurwetenschappen, Niet-EER, 1, MAE: ???, MAPE: ???
# M Environment and Society Studies, EER, 12, MAE: 10, MAPE: 5.0
# M Environment and Society Studies, NL, 43, MAE: 10, MAPE: 0.30303030303030304
# M Environment and Society Studies, Niet-EER, 6, MAE: 4, MAPE: 2.0
# M Europese Studies (joint degree), NL, 7, MAE: 0, MAPE: 0.0
# M Filosofie (1jr), EER, 1, MAE: ???, MAPE: ???
# M Filosofie (1jr), NL, 35, MAE: ???, MAPE: ???
# M Filosofie (1jr), Niet-EER, 1, MAE: ???, MAPE: ???
# M Filosofie (2jr), NL, 14, MAE: ???, MAPE: ???
# M Filosofie (2jr), Niet-EER, 1, MAE: ???, MAPE: ???
# M Filosofie (research), EER, 4, MAE: 0, MAPE: 0.0
# M Filosofie (research), NL, 15, MAE: 7, MAPE: 0.875
# M Filosofie (research), Niet-EER, 3, MAE: 1, MAPE: 0.5
# M Fiscaal Recht, NL, 36, MAE: 9, MAPE: 0.3333333333333333
# M Geneeskunde, EER, 2, MAE: 1, MAPE: 1.0
# M Geneeskunde, NL, 112, MAE: 41, MAPE: 0.2679738562091503
# M Geneeskunde, Niet-EER, 1, MAE: ???, MAPE: ???
# M Geschiedenis, EER, 2, MAE: 0, MAPE: 0.0
# M Geschiedenis, NL, 58, MAE: 0, MAPE: 0.0
# M Geschiedenis, Niet-EER, 2, MAE: ???, MAPE: ???
# M Historical, Literary and Cultural Studies (research), EER, 2, MAE: 0, MAPE: 0.0
# M Historical, Literary and Cultural Studies (research), NL, 11, MAE: 2, MAPE: 0.2222222222222222
# M Historical, Literary and Cultural Studies (research), Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative sarima error on: M Historical, Literary and Cultural Studies (research), onbekend
# Schur decomposition solver error.
# M Human Geography, EER, 14, MAE: 6, MAPE: 0.75
# M Human Geography, NL, 91, MAE: 40, MAPE: 0.7843137254901961
# M Human Geography, Niet-EER, 5, MAE: 4, MAPE: 4.0
# M Information Sciences, EER, 2, MAE: ???, MAPE: ???
# M Information Sciences, NL, 31, MAE: 20, MAPE: 1.8181818181818181
# M Information Sciences, Niet-EER, 5, MAE: ???, MAPE: ???
# M International and European Law, EER, 15, MAE: 0, MAPE: 0.0
# M International and European Law, NL, 28, MAE: 2, MAPE: 0.07692307692307693
# M International and European Law, Niet-EER, 4, MAE: 16, MAPE: 0.8
# M International and European Law, onbekend, 2, MAE: ???, MAPE: ???
# M Kunst- & cultuurwetenschappen, EER, 12, MAE: 10, MAPE: 5.0
# M Kunst- & cultuurwetenschappen, NL, 47, MAE: 14, MAPE: 0.42424242424242425
# M Kunst- & cultuurwetenschappen, Niet-EER, 4, MAE: 3, MAPE: 3.0
# M LVHO in de Bètawetenschappen, NL, 20, MAE: ???, MAPE: ???
# M LVHO in de Bètawetenschappen, Niet-EER, 6, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, EER, 1, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, NL, 37, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, Niet-EER, 1, MAE: ???, MAPE: ???
# M LVHO in de Taal en Cultuurwetenschappen, NL, 37, MAE: ???, MAPE: ???
# M LVHO in de Taal en Cultuurwetenschappen, Niet-EER, 1, MAE: ???, MAPE: ???
# M Letterkunde, EER, 2, MAE: ???, MAPE: ???
# M Letterkunde, NL, 33, MAE: 5, MAPE: 0.17857142857142858
# M Linguistics and Communication Sciences (research), EER, 3, MAE: 0, MAPE: 0.0
# M Linguistics and Communication Sciences (research), NL, 11, MAE: 9, MAPE: 4.5
# M Linguistics and Communication Sciences (research), Niet-EER, 4, MAE: 2, MAPE: 1.0
# Cumulative xgboost error on: M Linguistics and Communication Sciences (research), onbekend
# M Linguistics and Communication Sciences (research), onbekend, nan, MAE: ???, MAPE: ???
# M Mathematics, EER, 3, MAE: 2, MAPE: 2.0
# M Mathematics, NL, 14, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: M Spatial Planning, onbekend
# M Spatial Planning, onbekend, nan, MAE: ???, MAPE: ???
# M Taalwetenschappen, EER, 12, MAE: 5, MAPE: 0.7142857142857143
# M Taalwetenschappen, NL, 51, MAE: 25, MAPE: 0.9615384615384616
# M Taalwetenschappen, Niet-EER, 4, MAE: 2, MAPE: 1.0
# M Tandheelkunde, EER, 2, MAE: 1, MAPE: 1.0
# M Tandheelkunde, NL, 56, MAE: 7, MAPE: 0.1111111111111111
# M Tandheelkunde, Niet-EER, 2, MAE: ???, MAPE: ???
# M Theologie, NL, 2, MAE: 1, MAPE: 0.3333333333333333
# M Theologie, Niet-EER, 7, MAE: ???, MAPE: ???
# M Theologie & Religiewetenschappen, EER, 1, MAE: 1, MAPE: 0.5
# M Theologie & Religiewetenschappen, NL, 76, MAE: 21, MAPE: 0.38181818181818183
# M Theologie & Religiewetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# Final MAE: 12.2
# Final MAPE: 0.7075395735672175

# %%
total_mae = 0.0
total_mape = 0.0
count = 0.0

for _, row in data_to_predict.iterrows():
    programme = row['Croho groepeernaam']
    herkomst = row["Herkomst"]
    examtype = row["Examentype"]

    prediction = predict_with_xgboost(full_data, programme, examtype, herkomst, predict_year)

    nr_of_students = data_student_numbers_first_years[(data_student_numbers_first_years["Collegejaar"] == predict_year) & (data_student_numbers_first_years["Croho groepeernaam"] == programme) & 
                                                          (data_student_numbers_first_years["Herkomst"] == herkomst)]["Aantal_studenten"]

    mae = "???"
    mape = "???"
    if len(nr_of_students) > 0:
        mae = abs(nr_of_students.iloc[0] - final_prediction)
        mape = abs((nr_of_students.iloc[0] - final_prediction) / nr_of_students.iloc[0])

        total_mae += mae
        total_mape += mape
        count += 1.0

    print(f"{programme}, {herkomst}, {final_prediction}, MAE: {mae}, MAPE: {mape}")

print(f"Final MAE: {total_mae / count}")
print(f"Final MAPE: {total_mape / count}")
# Out:
# B Algemene Cultuurwetenschappen, EER, 2, MAE: 12, MAPE: 0.8571428571428571
# B Algemene Cultuurwetenschappen, NL, 2, MAE: 27, MAPE: 0.9310344827586207
# B Algemene Cultuurwetenschappen, Niet-EER, 2, MAE: 2, MAPE: 0.5
# B Artificial Intelligence, EER, 2, MAE: 45, MAPE: 0.9574468085106383
# B Artificial Intelligence, NL, 2, MAE: 151, MAPE: 0.9869281045751634
# B Artificial Intelligence, Niet-EER, 2, MAE: 13, MAPE: 0.8666666666666667
# B Artificial Intelligence, onbekend, 2, MAE: ???, MAPE: ???
# B Bedrijfskunde, EER, 2, MAE: 27, MAPE: 0.9310344827586207
# B Bedrijfskunde, NL, 2, MAE: 379, MAPE: 0.994750656167979
# B Bedrijfskunde, Niet-EER, 2, MAE: 9, MAPE: 0.8181818181818182
# B Bestuurskunde, NL, 2, MAE: 81, MAPE: 0.9759036144578314
# B Biology, EER, 2, MAE: 46, MAPE: 0.9583333333333334
# B Biology, NL, 2, MAE: 88, MAPE: 0.9777777777777777
# B Biology, Niet-EER, 2, MAE: 3, MAPE: 0.6
# B Biomedische Wetenschappen, EER, 2, MAE: ???, MAPE: ???
# B Biomedische Wetenschappen, NL, 2, MAE: 93, MAPE: 0.9789473684210527
# B Biomedische Wetenschappen, Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: B Biomedische Wetenschappen, onbekend
# B Biomedische Wetenschappen, onbekend, 2, MAE: ???, MAPE: ???
# B Chemistry, EER, 2, MAE: 5, MAPE: 0.7142857142857143
# B Chemistry, NL, 2, MAE: 26, MAPE: 0.9285714285714286
# B Chemistry, Niet-EER, 2, MAE: 0, MAPE: 0.0
# B Communicatie- en Informatiewetenschappen, EER, 2, MAE: 16, MAPE: 0.8888888888888888
# B Communicatie- en Informatiewetenschappen, NL, 2, MAE: 65, MAPE: 0.9701492537313433
# B Communicatie- en Informatiewetenschappen, Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: B Communicatie- en Informatiewetenschappen, onbekend
# B Communicatie- en Informatiewetenschappen, onbekend, 2, MAE: ???, MAPE: ???
# B Communicatiewetenschap, NL, 2, MAE: 102, MAPE: 0.9807692307692307
# B Computing Science, EER, 2, MAE: 57, MAPE: 0.9661016949152542
# B Computing Science, NL, 2, MAE: 79, MAPE: 0.9753086419753086
# B Computing Science, Niet-EER, 2, MAE: 21, MAPE: 0.9130434782608695
# B Culturele Antropologie en Ontwikkelingssociologie, NL, 2, MAE: 59, MAPE: 0.9672131147540983
# B Duitse Taal en Cultuur, NL, 2, MAE: 7, MAPE: 0.7777777777777778
# B Duitse Taal en Cultuur, Niet-EER, 2, MAE: ???, MAPE: ???
# B Economie en Bedrijfseconomie, EER, 2, MAE: 17, MAPE: 0.8947368421052632
# B Economie en Bedrijfseconomie, NL, 2, MAE: 138, MAPE: 0.9857142857142858
# B Economie en Bedrijfseconomie, Niet-EER, 2, MAE: 5, MAPE: 0.7142857142857143
# B English Language and Culture, EER, 2, MAE: 12, MAPE: 0.8571428571428571
# B English Language and Culture, NL, 2, MAE: 62, MAPE: 0.96875
# B English Language and Culture, Niet-EER, 2, MAE: 2, MAPE: 0.5
# B European Law School, EER, 2, MAE: 1, MAPE: 1.0
# B European Law School, NL, 2, MAE: 59, MAPE: 0.9672131147540983
# B European Law School, Niet-EER, 2, MAE: ???, MAPE: ???
# B Filosofie, EER, 2, MAE: 28, MAPE: 0.9333333333333333
# B Filosofie, NL, 2, MAE: 96, MAPE: 0.9795918367346939
# B Filosofie, Niet-EER, 2, MAE: 1, MAPE: 0.3333333333333333
# B Filosofie, onbekend, 2, MAE: ???, MAPE: ???
# B Geneeskunde, EER, 2, MAE: 1, MAPE: 1.0
# B Geneeskunde, NL, 2, MAE: 323, MAPE: 0.9938461538461538
# B Geneeskunde, Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: B Geneeskunde, onbekend
# B Geneeskunde, onbekend, 2, MAE: ???, MAPE: ???
# B Geografie, Planologie en Milieu, EER, 2, MAE: ???, MAPE: ???
# B Geografie, Planologie en Milieu, NL, 2, MAE: 140, MAPE: 0.9859154929577465
# B Tandheelkunde, Niet-EER, 2, MAE: 1, MAPE: 1.0
# B Tandheelkunde, onbekend, 2, MAE: ???, MAPE: ???
# B Theologie, NL, 2, MAE: 9, MAPE: 0.8181818181818182
# B Wiskunde, EER, 2, MAE: ???, MAPE: ???
# B Wiskunde, NL, 2, MAE: 52, MAPE: 0.9629629629629629
# Cumulative xgboost error on: B Wiskunde, Niet-EER
# B Wiskunde, Niet-EER, 2, MAE: ???, MAPE: ???
# M Anthropology and Development Studies, EER, 2, MAE: 1, MAPE: 0.3333333333333333
# M Anthropology and Development Studies, NL, 2, MAE: 7, MAPE: 0.7777777777777778
# M Anthropology and Development Studies, Niet-EER, 2, MAE: 1, MAPE: 1.0
# M Artificial Intelligence, EER, 2, MAE: 10, MAPE: 0.8333333333333334
# M Artificial Intelligence, NL, 2, MAE: 53, MAPE: 0.9636363636363636
# M Artificial Intelligence, Niet-EER, 2, MAE: 3, MAPE: 0.6
# M Behavioural Science (research), EER, 2, MAE: 14, MAPE: 0.875
# M Behavioural Science (research), NL, 2, MAE: 20, MAPE: 0.9090909090909091
# M Behavioural Science (research), Niet-EER, 2, MAE: 4, MAPE: 0.6666666666666666
# M Bestuurskunde, EER, 2, MAE: 1, MAPE: 1.0
# M Bestuurskunde, NL, 2, MAE: 47, MAPE: 0.9591836734693877
# M Bestuurskunde, Niet-EER, 2, MAE: 1, MAPE: 1.0
# M Biology, EER, 2, MAE: 7, MAPE: 0.7777777777777778
# M Biology, NL, 2, MAE: 33, MAPE: 0.9428571428571428
# M Biology, Niet-EER, 2, MAE: 4, MAPE: 0.6666666666666666
# M Biomedical Sciences, EER, 2, MAE: 15, MAPE: 0.8823529411764706
# M Biomedical Sciences, NL, 2, MAE: 120, MAPE: 0.9836065573770492
# M Biomedical Sciences, Niet-EER, 2, MAE: 11, MAPE: 0.8461538461538461
# M Business Administration, EER, 2, MAE: 17, MAPE: 0.8947368421052632
# M Business Administration, NL, 2, MAE: 315, MAPE: 0.9936908517350158
# M Business Administration, Niet-EER, 2, MAE: 3, MAPE: 0.6
# M Cognitive Neuroscience (research), EER, 2, MAE: 34, MAPE: 0.9444444444444444
# M Cognitive Neuroscience (research), NL, 2, MAE: 25, MAPE: 0.9259259259259259
# M Cognitive Neuroscience (research), Niet-EER, 2, MAE: 10, MAPE: 0.8333333333333334
# M Communicatie- & informatiewetenschappen, EER, 2, MAE: 3, MAPE: 0.6
# M Communicatie- & informatiewetenschappen, NL, 2, MAE: 72, MAPE: 0.972972972972973
# M Communicatie- & informatiewetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# Cumulative xgboost error on: M Communicatie- & informatiewetenschappen, onbekend
# M Communicatie- & informatiewetenschappen, onbekend, 2, MAE: ???, MAPE: ???
# M Communicatiewetenschap, NL, 2, MAE: 66, MAPE: 0.9705882352941176
# M Computing Science, EER, 2, MAE: 18, MAPE: 0.9
# M Computing Science, NL, 2, MAE: 47, MAPE: 0.9591836734693877
# M Computing Science, Niet-EER, 2, MAE: 9, MAPE: 0.8181818181818182
# Cumulative xgboost error on: M Computing Science, onbekend
# M Computing Science, onbekend, 2, MAE: ???, MAPE: ???
# M Curriculumontwikkeling voor Primair Onderwijs, NL, 2, MAE: 7, MAPE: 0.7777777777777778
# M Economics, EER, 2, MAE: 3, MAPE: 0.6
# M Economics, NL, 2, MAE: 105, MAPE: 0.9813084112149533
# M Economics, Niet-EER, 2, MAE: 1, MAPE: 1.0
# Cumulative xgboost error on: M Educatie in de Mens- en Maatschappijwetenschappen, EER
# M Educatie in de Mens- en Maatschappijwetenschappen, EER, 2, MAE: ???, MAPE: ???
# M Educatie in de Mens- en Maatschappijwetenschappen, NL, 2, MAE: 19, MAPE: 0.9047619047619048
# M Educatie in de Mens- en Maatschappijwetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# Cumulative xgboost error on: M Educatie in de Taal- en Cultuurwetenschappen, EER
# M Educatie in de Taal- en Cultuurwetenschappen, EER, 2, MAE: ???, MAPE: ???
# M Educatie in de Taal- en Cultuurwetenschappen, NL, 2, MAE: ???, MAPE: ???
# M Educatie in de Taal- en Cultuurwetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# M Environment and Society Studies, EER, 2, MAE: 0, MAPE: 0.0
# M Environment and Society Studies, NL, 2, MAE: 31, MAPE: 0.9393939393939394
# M Environment and Society Studies, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Europese Studies (joint degree), NL, 2, MAE: 5, MAPE: 0.7142857142857143
# M Filosofie (1jr), EER, 2, MAE: ???, MAPE: ???
# M Filosofie (1jr), NL, 2, MAE: ???, MAPE: ???
# M Filosofie (1jr), Niet-EER, 2, MAE: ???, MAPE: ???
# M Filosofie (2jr), NL, 2, MAE: ???, MAPE: ???
# M Filosofie (2jr), Niet-EER, 2, MAE: ???, MAPE: ???
# M Filosofie (research), EER, 2, MAE: 2, MAPE: 0.5
# M Filosofie (research), NL, 2, MAE: 6, MAPE: 0.75
# M Filosofie (research), Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Fiscaal Recht, NL, 2, MAE: 25, MAPE: 0.9259259259259259
# M Geneeskunde, EER, 2, MAE: 1, MAPE: 1.0
# M Geneeskunde, NL, 2, MAE: 151, MAPE: 0.9869281045751634
# M Geneeskunde, Niet-EER, 2, MAE: ???, MAPE: ???
# M Geschiedenis, EER, 2, MAE: 0, MAPE: 0.0
# M Geschiedenis, NL, 2, MAE: 56, MAPE: 0.9655172413793104
# M Geschiedenis, Niet-EER, 2, MAE: ???, MAPE: ???
# M Historical, Literary and Cultural Studies (research), EER, 2, MAE: 0, MAPE: 0.0
# M Historical, Literary and Cultural Studies (research), NL, 2, MAE: 7, MAPE: 0.7777777777777778
# M Historical, Literary and Cultural Studies (research), Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: M Historical, Literary and Cultural Studies (research), onbekend
# M Historical, Literary and Cultural Studies (research), onbekend, 2, MAE: ???, MAPE: ???
# M Human Geography, EER, 2, MAE: 6, MAPE: 0.75
# M Human Geography, NL, 2, MAE: 49, MAPE: 0.9607843137254902
# M Human Geography, Niet-EER, 2, MAE: 1, MAPE: 1.0
# M Information Sciences, EER, 2, MAE: ???, MAPE: ???
# M Information Sciences, NL, 2, MAE: 9, MAPE: 0.8181818181818182
# M Information Sciences, Niet-EER, 2, MAE: ???, MAPE: ???
# M International and European Law, EER, 2, MAE: 13, MAPE: 0.8666666666666667
# M International and European Law, NL, 2, MAE: 24, MAPE: 0.9230769230769231
# M International and European Law, Niet-EER, 2, MAE: 18, MAPE: 0.9
# M International and European Law, onbekend, 2, MAE: ???, MAPE: ???
# M Kunst- & cultuurwetenschappen, EER, 2, MAE: 0, MAPE: 0.0
# M Kunst- & cultuurwetenschappen, NL, 2, MAE: 31, MAPE: 0.9393939393939394
# M Kunst- & cultuurwetenschappen, Niet-EER, 2, MAE: 1, MAPE: 1.0
# M LVHO in de Bètawetenschappen, NL, 2, MAE: ???, MAPE: ???
# M LVHO in de Bètawetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, EER, 2, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, NL, 2, MAE: ???, MAPE: ???
# M LVHO in de Mens- en Maatschappijwetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# M LVHO in de Taal en Cultuurwetenschappen, NL, 2, MAE: ???, MAPE: ???
# M LVHO in de Taal en Cultuurwetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# M Letterkunde, EER, 2, MAE: ???, MAPE: ???
# M Letterkunde, NL, 2, MAE: 26, MAPE: 0.9285714285714286
# M Linguistics and Communication Sciences (research), EER, 2, MAE: 1, MAPE: 0.3333333333333333
# M Linguistics and Communication Sciences (research), NL, 2, MAE: 0, MAPE: 0.0
# M Linguistics and Communication Sciences (research), Niet-EER, 2, MAE: 0, MAPE: 0.0
# Cumulative xgboost error on: M Linguistics and Communication Sciences (research), onbekend
# M Linguistics and Communication Sciences (research), onbekend, 2, MAE: ???, MAPE: ???
# M Mathematics, EER, 2, MAE: 1, MAPE: 1.0
# M Mathematics, NL, 2, MAE: 12, MAPE: 0.8571428571428571
# M Mathematics, Niet-EER, 2, MAE: ???, MAPE: ???
# M Medical Biology, EER, 2, MAE: 12, MAPE: 0.8571428571428571
# M Medical Biology, NL, 2, MAE: 84, MAPE: 0.9767441860465116
# M Medical Biology, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Molecular Mechanisms of Disease (research), EER, 2, MAE: 0, MAPE: 0.0
# M Molecular Mechanisms of Disease (research), NL, 2, MAE: 2, MAPE: 0.5
# M Molecular Mechanisms of Disease (research), Niet-EER, 2, MAE: 1, MAPE: 0.3333333333333333
# M Molecular Sciences, EER, 2, MAE: 6, MAPE: 0.75
# M Molecular Sciences, NL, 2, MAE: 28, MAPE: 0.9333333333333333
# M Molecular Sciences, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Nederlands Recht, NL, 2, MAE: 267, MAPE: 0.9925650557620818
# M Nederlands Recht, Niet-EER, 2, MAE: ???, MAPE: ???
# M Noord-Amerika Studies, EER, 2, MAE: 0, MAPE: 0.0
# M Noord-Amerika Studies, NL, 2, MAE: 8, MAPE: 0.8
# M Noord-Amerika Studies, Niet-EER, 2, MAE: ???, MAPE: ???
# M Notarieel Recht, NL, 2, MAE: 51, MAPE: 0.9622641509433962
# M Onderneming en Recht (research), NL, 2, MAE: 2, MAPE: 0.5
# M Onderneming en Recht (research), Niet-EER, 2, MAE: ???, MAPE: ???
# M Onderwijswetenschappen, EER, 2, MAE: 1, MAPE: 1.0
# M Onderwijswetenschappen, NL, 2, MAE: 26, MAPE: 0.9285714285714286
# M Oudheidstudies, NL, 2, MAE: 3, MAPE: 0.6
# M Pedagogische Wetenschappen, EER, 2, MAE: ???, MAPE: ???
# M Pedagogische Wetenschappen, NL, 2, MAE: 236, MAPE: 0.9915966386554622
# M Pedagogische Wetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# M Physics and Astronomy, EER, 2, MAE: 7, MAPE: 0.7777777777777778
# M Physics and Astronomy, NL, 2, MAE: 22, MAPE: 0.9166666666666666
# M Physics and Astronomy, Niet-EER, 2, MAE: 1, MAPE: 0.3333333333333333
# M Political Science, EER, 2, MAE: 5, MAPE: 0.7142857142857143
# M Political Science, NL, 2, MAE: 74, MAPE: 0.9736842105263158
# M Political Science, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Political Science, onbekend, 2, MAE: ???, MAPE: ???
# M Psychologie, EER, 2, MAE: 25, MAPE: 0.9259259259259259
# M Psychologie, NL, 2, MAE: 119, MAPE: 0.9834710743801653
# M Psychologie, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Social and Cultural Science (research), EER, 2, MAE: ???, MAPE: ???
# M Social and Cultural Science (research), NL, 2, MAE: ???, MAPE: ???
# M Social and Cultural Science (research), Niet-EER, 2, MAE: ???, MAPE: ???
# M Sociologie, NL, 2, MAE: 13, MAPE: 0.8666666666666667
# M Sociologie, Niet-EER, 2, MAE: ???, MAPE: ???
# M Spatial Planning, EER, 2, MAE: 1, MAPE: 0.3333333333333333
# M Spatial Planning, NL, 2, MAE: 75, MAPE: 0.974025974025974
# M Spatial Planning, Niet-EER, 2, MAE: 2, MAPE: 0.5
# Cumulative xgboost error on: M Spatial Planning, onbekend
# M Spatial Planning, onbekend, 2, MAE: ???, MAPE: ???
# M Taalwetenschappen, EER, 2, MAE: 5, MAPE: 0.7142857142857143
# M Taalwetenschappen, NL, 2, MAE: 24, MAPE: 0.9230769230769231
# M Taalwetenschappen, Niet-EER, 2, MAE: 0, MAPE: 0.0
# M Tandheelkunde, EER, 2, MAE: 1, MAPE: 1.0
# M Tandheelkunde, NL, 2, MAE: 61, MAPE: 0.9682539682539683
# M Tandheelkunde, Niet-EER, 2, MAE: ???, MAPE: ???
# M Theologie, NL, 2, MAE: 1, MAPE: 0.3333333333333333
# M Theologie, Niet-EER, 2, MAE: ???, MAPE: ???
# M Theologie & Religiewetenschappen, EER, 2, MAE: 0, MAPE: 0.0
# M Theologie & Religiewetenschappen, NL, 2, MAE: 53, MAPE: 0.9636363636363636
# M Theologie & Religiewetenschappen, Niet-EER, 2, MAE: ???, MAPE: ???
# Final MAE: 39.5414364640884
# Final MAPE: 0.751314575548972
