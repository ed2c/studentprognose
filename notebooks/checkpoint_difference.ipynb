# %%
import pandas as pd
import numpy as np

# %%
data_cumulative_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_cumulative_1.xlsx")
old_data_cumulative_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_cumulative_1.xlsx")

data_individual_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_individual_1.xlsx")
old_data_individual_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_individual_1.xlsx")

# %%
data_cumulative_2 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_cumulative_2.xlsx")
old_data_cumulative_2 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_cumulative_2.xlsx")

# %%
data_individual_2 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_individual_2.xlsx")
old_data_individual_2 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_individual_2.xlsx")

# %%
data_exog_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_exog_1.xlsx")
old_data_exog_1 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_exog_1.xlsx")

# %%
data_individual_1_5 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\data_individual_1-5.xlsx")
old_data_individual_1_5 = pd.read_excel("\\\\ru.nl\\wrkgrp\\TeamIR\\Man_info\\Student Analytics\\Prognosemodel RU\\Syntax\\Python\\studentprognose\\data\\test\\old_data_individual_1-5.xlsx")
new_data_individual_1_5 = pd.read_excel("../../Backup3/data_individual_1-5_new.xlsx")

# %%
print(f"Preprocessed data_cumulative: {data_cumulative_1.equals(old_data_cumulative_1)}")
print(f"Preprocessed data_individual: {data_individual_1.equals(old_data_individual_1)}")

print(f"Inschrijfpredictie data_individual: {data_individual_1_5.equals(old_data_individual_1_5)}")
# print(f"Before prediction data_individual: {data_individual_2.equals(old_data_individual_2)}")

print(f"Data_exog: {data_exog_1.equals(old_data_exog_1)}")
# Out:
# Preprocessed data_cumulative: True
# Preprocessed data_individual: True
# Inschrijfpredictie data_individual: False
# Data_exog: False

# %%
print(f"Inschrijfpredictie data_individual: {data_individual_1_5.equals(old_data_individual_1_5)}")
print(f"Inschrijfpredictie data_individual: {new_data_individual_1_5.equals(old_data_individual_1_5)}")
print(f"Inschrijfpredictie data_individual: {new_data_individual_1_5.equals(data_individual_1_5)}")
# Out:
# Inschrijfpredictie data_individual: False
# Inschrijfpredictie data_individual: False
# Inschrijfpredictie data_individual: False

# %%
print(f"Before prediction data_cumulative: {data_cumulative_2.equals(old_data_cumulative_2)}")
# Out:
# Before prediction data_cumulative: False

# %%
print(data_cumulative_2)
print(old_data_cumulative_2)
# Out:
#         Weeknummer  Collegejaar Faculteit Examentype  Herkomst  \
# 0                1         2011       FdL   Bachelor       EER
# 1                2         2011       FdL   Bachelor       EER
# 2                3         2011       FdL   Bachelor       EER
# 3                4         2011       FdL   Bachelor       EER
# 4                5         2011       FdL   Bachelor       EER
# ...            ...          ...       ...        ...       ...
# 140578          47         2024      FFTR     Master  onbekend
# 140579          48         2024      FFTR     Master  onbekend
# 140580          49         2024      FFTR     Master  onbekend
# 140581          50         2024      FFTR     Master  onbekend
# 140582          51         2024      FFTR     Master  onbekend
#
#                         Croho groepeernaam  Gewogen vooraanmelders  \
# 0          B Algemene Cultuurwetenschappen                     1.0
# 1          B Algemene Cultuurwetenschappen                     1.0
# ...

# %%
df1 = data_cumulative_2
df2 = old_data_cumulative_2

# %%
df1[~df1.apply(tuple,1).isin(df2.apply(tuple,1))]
# Out:
#         Weeknummer  Collegejaar Faculteit Examentype Herkomst  \
# 7045             1         2012       FdL   Bachelor       NL
# 7046             3         2012       FdL   Bachelor       NL
# 7047             4         2012       FdL   Bachelor       NL
# 7048             5         2012       FdL   Bachelor       NL
# 7049             6         2012       FdL   Bachelor       NL
# ...            ...          ...       ...        ...      ...
# 130272          48         2023       Fdr     Master       NL
# 130273          49         2023       Fdr     Master       NL
# 130274          50         2023       Fdr     Master       NL
# 130275          51         2023       Fdr     Master       NL
# 130276          52         2023       Fdr     Master       NL
#
#                      Croho groepeernaam  Gewogen vooraanmelders  \
# 7045    B Algemene Cultuurwetenschappen                     3.0
# 7046    B Algemene Cultuurwetenschappen                     3.0
# ...

# %%
df2[~df2.apply(tuple,1).isin(df1.apply(tuple,1))]
# Out:
#         Weeknummer  Collegejaar Faculteit Examentype Herkomst  \
# 7045             1         2012       FdL   Bachelor       NL
# 7046             3         2012       FdL   Bachelor       NL
# 7047             4         2012       FdL   Bachelor       NL
# 7048             5         2012       FdL   Bachelor       NL
# 7049             6         2012       FdL   Bachelor       NL
# ...            ...          ...       ...        ...      ...
# 130548          48         2023       Fdr     Master       NL
# 130549          49         2023       Fdr     Master       NL
# 130550          50         2023       Fdr     Master       NL
# 130551          51         2023       Fdr     Master       NL
# 130552          52         2023       Fdr     Master       NL
#
#                      Croho groepeernaam  Gewogen vooraanmelders  \
# 7045    B Algemene Cultuurwetenschappen                     3.0
# 7046    B Algemene Cultuurwetenschappen                     3.0
# ...

# %%
df1 = data_cumulative_2[data_cumulative_2["Collegejaar"] == 2023]
df2 = old_data_cumulative_2[old_data_cumulative_2["Collegejaar"] == 2023]

print(f"Before prediction data_cumulative: {df1.equals(df2)}")

df3 = df1.merge(df2,indicator = True, how='left').loc[lambda x : x['_merge']!='both']
df3.to_excel("test.xlsx", index=False)
# Out:
# Before prediction data_cumulative: False

# %%
df1[~df1.apply(tuple,1).isin(df2.apply(tuple,1))]
# Out:
#         Weeknummer  Collegejaar Faculteit Examentype Herkomst  \
# 122072           1         2023       FdL   Bachelor      EER
# 122073           2         2023       FdL   Bachelor      EER
# 122074           3         2023       FdL   Bachelor      EER
# 122075           4         2023       FdL   Bachelor      EER
# 122076           5         2023       FdL   Bachelor      EER
# ...            ...          ...       ...        ...      ...
# 130272          48         2023       Fdr     Master       NL
# 130273          49         2023       Fdr     Master       NL
# 130274          50         2023       Fdr     Master       NL
# 130275          51         2023       Fdr     Master       NL
# 130276          52         2023       Fdr     Master       NL
#
#                      Croho groepeernaam  Gewogen vooraanmelders  \
# 122072  B Algemene Cultuurwetenschappen                   10.25
# 122073  B Algemene Cultuurwetenschappen                   12.83
# ...

# %%
df2[~df2.apply(tuple,1).isin(df1.apply(tuple,1))]
# Out:
#         Weeknummer  Collegejaar Faculteit Examentype Herkomst  \
# 122276           1         2023       FdL   Bachelor      EER
# 122277           2         2023       FdL   Bachelor      EER
# 122278           3         2023       FdL   Bachelor      EER
# 122279           4         2023       FdL   Bachelor      EER
# 122280           5         2023       FdL   Bachelor      EER
# ...            ...          ...       ...        ...      ...
# 130548          48         2023       Fdr     Master       NL
# 130549          49         2023       Fdr     Master       NL
# 130550          50         2023       Fdr     Master       NL
# 130551          51         2023       Fdr     Master       NL
# 130552          52         2023       Fdr     Master       NL
#
#                      Croho groepeernaam  Gewogen vooraanmelders  \
# 122276  B Algemene Cultuurwetenschappen                   10.25
# 122277  B Algemene Cultuurwetenschappen                   12.83
# ...

# %%
df1.merge(df2,indicator = True, how='left').loc[lambda x : x['_merge']!='both']
# Out:
#       Weeknummer  Collegejaar Faculteit Examentype Herkomst  \
# 0              1         2023       FdL   Bachelor      EER
# 1              2         2023       FdL   Bachelor      EER
# 2              3         2023       FdL   Bachelor      EER
# 3              4         2023       FdL   Bachelor      EER
# 4              5         2023       FdL   Bachelor      EER
# ...          ...          ...       ...        ...      ...
# 8200          48         2023       Fdr     Master       NL
# 8201          49         2023       Fdr     Master       NL
# 8202          50         2023       Fdr     Master       NL
# 8203          51         2023       Fdr     Master       NL
# 8204          52         2023       Fdr     Master       NL
#
#                    Croho groepeernaam  Gewogen vooraanmelders  \
# 0     B Algemene Cultuurwetenschappen                   10.25
# 1     B Algemene Cultuurwetenschappen                   12.83
# ...
